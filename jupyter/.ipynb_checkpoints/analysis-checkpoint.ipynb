# %%
import pandas as pd
import pymongo as pm

# %%
connect_uri = '' # insert database uri here

# %%
client = pm.MongoClient(connect_uri)

# %%
db = client.songs
songs = db['songs']

# %%
rap_songs = list(songs.find({'genre': 'rap'}))

# %%
def dict_merge(dict1, dict2):
    return(dict2.update(dict1))

# %%
song1 = {
    'name': rap_songs[0]['name'],
    'genre': rap_songs[0]['genre'],
    'explicit': rap_songs[0]['explicit']
}

song1_ = {**song1, **rap_songs[0]['audio-features']}

song1_
# Out:
# {'name': 'Lemonade (feat. Gunna, Don Toliver & NAV)',
#  'genre': 'rap',
#  'explicit': True,
#  'danceability': 0.8,
#  'energy': 0.658,
#  'key': 1,
#  'loudness': -6.142,
#  'mode': 0,
#  'speechiness': 0.079,
#  'acousticness': 0.25,
#  'instrumentalness': 0,
#  'liveness': 0.111,
#  'valence': 0.462,
#  'tempo': 140.042,
#  'type': 'audio_features',
#  'id': '7hxHWCCAIIxFLCzvDgnQHX',
#  'uri': 'spotify:track:7hxHWCCAIIxFLCzvDgnQHX',
#  'track_href': 'https://api.spotify.com/v1/tracks/7hxHWCCAIIxFLCzvDgnQHX',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7hxHWCCAIIxFLCzvDgnQHX',
#  'duration_ms': 195429,
#  'time_signature': 4}

# %%
rap_list = []
for song in rap_songs:
    song_dict = {**{
    'name': song['name'],
    'genre': song['genre'],
    'explicit': song['explicit']
    }, **song['audio-features']}
    
    rap_list.append(song_dict)

# %%
rap_df = pd.DataFrame(rap_list)

# %%
rap_df.loc[rap_df['error'].notnull()]
# Out:
#                                          name genre  explicit  danceability  \
# 325  #1543 - Brian Muraresku & Graham Hancock   rap      True           NaN
#
#      energy  key  loudness  mode  speechiness  acousticness  ...  valence  \
# 325     NaN  NaN       NaN   NaN          NaN           NaN  ...      NaN
#
#      tempo  type   id  uri track_href analysis_url duration_ms time_signature  \
# 325    NaN   NaN  NaN  NaN        NaN          NaN         NaN            NaN
#
#                                                 error
# 325  {'status': 404, 'message': 'analysis not found'}
#
# [1 rows x 22 columns]

# %%
rap_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326 entries, 0 to 325
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              326 non-null    object
#  1   genre             326 non-null    object
#  2   explicit          326 non-null    bool
#  3   danceability      325 non-null    float64
#  4   energy            325 non-null    float64
#  5   key               325 non-null    float64
#  6   loudness          325 non-null    float64
#  7   mode              325 non-null    float64
#  8   speechiness       325 non-null    float64
#  9   acousticness      325 non-null    float64
#  10  instrumentalness  325 non-null    float64
#  11  liveness          325 non-null    float64
#  12  valence           325 non-null    float64
#  13  tempo             325 non-null    float64
#  14  type              325 non-null    object
#  15  id                325 non-null    object
# ...

# %%
rap_df.head()
# Out:
#                                                 name genre  explicit  \
# 0          Lemonade (feat. Gunna, Don Toliver & NAV)   rap      True
# 1                                24 (feat. Lil Baby)   rap      True
# 2  Moonwalking in Calabasas (feat. Blueface) - Remix   rap      True
# 3                                             Runnin   rap      True
# 4                                           PRACTICE   rap      True
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  ...  \
# 0         0.800   0.658   1.0    -6.142   0.0       0.0790       0.25000  ...
# 1         0.868   0.638   2.0    -7.746   1.0       0.0736       0.14600  ...
# 2         0.928   0.341  11.0   -10.196   0.0       0.1030       0.06140  ...
# 3         0.819   0.626  10.0    -4.574   0.0       0.2020       0.00748  ...
# 4         0.849   0.536   1.0    -7.307   1.0       0.3490       0.02390  ...
#
#    valence    tempo            type                      id  \
# ...

# %%
rap_df.pop('error')
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#                              ...
# 321                                                 NaN
# 322                                                 NaN
# 323                                                 NaN
# 324                                                 NaN
# 325    {'status': 404, 'message': 'analysis not found'}
# Name: error, Length: 326, dtype: object

# %%
rap_df = rap_df.dropna()

# %%
rap_df
# Out:
#                                                   name genre  explicit  \
# 0            Lemonade (feat. Gunna, Don Toliver & NAV)   rap      True
# 1                                  24 (feat. Lil Baby)   rap      True
# 2    Moonwalking in Calabasas (feat. Blueface) - Remix   rap      True
# 3                                               Runnin   rap      True
# 4                                             PRACTICE   rap      True
# ..                                                 ...   ...       ...
# 320                                          All Right   rap      True
# 321                                             Clowns   rap      True
# 322                                              Bilan   rap      True
# 323                                             Zigzag   rap      True
# 324                                     Radicalisation   rap      True
#
#      danceability  energy   key  loudness  mode  speechiness  acousticness  \
# ...

# %%
print(rap_df)
# Out:
#                                                   name genre  explicit  \
# 0            Lemonade (feat. Gunna, Don Toliver & NAV)   rap      True
# 1                                  24 (feat. Lil Baby)   rap      True
# 2    Moonwalking in Calabasas (feat. Blueface) - Remix   rap      True
# 3                                               Runnin   rap      True
# 4                                             PRACTICE   rap      True
# ..                                                 ...   ...       ...
# 320                                          All Right   rap      True
# 321                                             Clowns   rap      True
# 322                                              Bilan   rap      True
# 323                                             Zigzag   rap      True
# 324                                     Radicalisation   rap      True
#
#      danceability  energy   key  loudness  mode  speechiness  acousticness  \
# ...
